# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read data from file '2018-2020Accidents.csv'
data = pd.read_csv("2018-2020Accidents.csv")

data
# Out:
#       Year(4)-CountyCode(2)-MunicipalityCode(2)-CaseNumber County Name  \
# 0                                       2018130118-00222      MONMOUTH
# 1                                       2018130118-03831      MONMOUTH
# 2                                       2018130118-05620      MONMOUTH
# 3                                       2018130118-06451      MONMOUTH
# 4                                       2018130118-06456      MONMOUTH
# ...                                                  ...           ...
# 49921                                  2020135320WB19506      MONMOUTH
# 49922                                  2020135320WB19605      MONMOUTH
# 49923                                  2020135320WB19723      MONMOUTH
# 49924                                  2020135320WB19767      MONMOUTH
# 49925                                  2020135320WB19771      MONMOUTH
#
#            Municipality Name  Crash Date Crash Day of Week  Crash Time  \
# ...

# %%
# remove all rows with latitude or longitude of NaN
data_with_coords = data.dropna(subset=['Latitude', 'Longitude'])
data_with_coords
# Out:
#       Year(4)-CountyCode(2)-MunicipalityCode(2)-CaseNumber County Name  \
# 35                                     2018130218AT00012      MONMOUTH
# 38                                     2018130218AT00257      MONMOUTH
# 40                                     2018130218AT00306      MONMOUTH
# 42                               2018130218AT00466/18-14      MONMOUTH
# 43                                     2018130218AT00624      MONMOUTH
# ...                                                  ...           ...
# 49893                                  2020135320WB17807      MONMOUTH
# 49907                                  2020135320WB18686      MONMOUTH
# 49908                                  2020135320WB18791      MONMOUTH
# 49909                                  2020135320WB18852      MONMOUTH
# 49910                                  2020135320WB18853      MONMOUTH
#
#            Municipality Name  Crash Date Crash Day of Week  Crash Time  \
# ...

# %%
# Check values of important columns
'''print(data_with_coords["Total Injured"].value_counts())
print(data_with_coords["Road Grade"].value_counts())
print(data_with_coords["Road Surface Type"].value_counts())
print(data_with_coords["Surface Condition"].value_counts())
print(data_with_coords["Light Condition"].value_counts())'''
print(data_with_coords["Latitude"].min(), data_with_coords["Longitude"].min(), data_with_coords["Latitude"].max(), data_with_coords["Longitude"].max())
# Out:
# 38.12526 73.4454 41.39383 75.5212
