# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_2020 = pd.read_csv("2020Accidents.csv")
data_2019 = pd.read_csv("2019Accidents.csv")
data_2018 = pd.read_csv("2018Accidents.csv")

data_2020
# Out:
#       Year(4)-CountyCode(2)-MunicipalityCode(2)-CaseNumber County Name  \
# 0                                       2020130120-02466      MONMOUTH
# 1                                       2020130120-02768      MONMOUTH
# 2                                       2020130120-06066      MONMOUTH
# 3                                       2020130120-06070      MONMOUTH
# 4                                       2020130120-09161      MONMOUTH
# ...                                                  ...           ...
# 13347                                  2020135320WB19506      MONMOUTH
# 13348                                  2020135320WB19605      MONMOUTH
# 13349                                  2020135320WB19723      MONMOUTH
# 13350                                  2020135320WB19767      MONMOUTH
# 13351                                  2020135320WB19771      MONMOUTH
#
#            Municipality Name  Crash Date Crash Day of Week  Crash Time  \
# ...

# %%
#plt.scatter(data_2020["Posted Speed"], data_2020["Total Killed"])
print(data_2020["Total Killed"].value_counts())
# Out:
# 0    13311
# 1       40
# 2        1
# Name: Total Killed, dtype: int64
